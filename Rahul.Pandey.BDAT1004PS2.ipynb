# %% [markdown]
# # Problem Set 2

# %% [markdown]
# ### Question 1

# %%
a = 0
def b():
    global a
    a = c(a)
def c(a):
    return a + 2

# %%
b()

# %%
b()

# %%
b()

# %%
a
# Out:
# 6

# %% [markdown]
# ##### First we define a as a global variable "a" initially given value 0 to a and crateing 2 functoion 'b' and 'c'.The b function calls c(a) and updates 'a'by adding 2 to its current value. When we execute b() three times, each call to c(a) increases the value of a by 2, so after the third call, a becomes 6.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Function fileLength(), given to you, takes the name of a file as input and returns the length of the file:

# %%
def file_length(file_name):
    file = open(file_name)
    contents = file.read()
    file.close()
    print(len(contents))

# %%
file_length("midterm.py")
# Out:
# 181

# %%
def file_length(file_name):
    try:                             
        file = open(file_name)
        content = file.read()
        file.close()
        print(len(contents))
    except FileNotFoundError:
        print("The file {} is not found".format(file_name))

# %%
file_length("idterm.txt")
# Out:
# The file idterm.txt is not found

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Write a class named Marsupial that can be used as shown below:

# %%
class Marsupial:
    def __init__(self):      
        self.collection_lst = []
    
    def put_in_pouch(self,collection):
        self.collection_lst.append(collection)
        
    def pouch_content(self):
        print(self.collection_lst)

# %%
m=Marsupial()

# %%
m.put_in_pouch("test")
m.put_in_pouch("firetruck")
m.put_in_pouch("kitten")

# %%
m.pouch_content()
# Out:
# ['test', 'firetruck', 'kitten']

# %%
class Kangaroo(Marsupial):     
    def __init__(self, x,y):
        super().__init__()    
        self.x=x
        self.y=y
        
    def jump(self,dx,dy):
        self.x+=dx
        self.y+=dy
    
    def __str__(self):
        return "I am a Kangaroo located at coordinate ({},{})".format(self.x,self.y)

# %%
k = Kangaroo(0,0)

# %%
print(k)
# Out:
# I am a Kangaroo located at coordinate (0,0)

# %%
k.put_in_pouch("doll")
k.put_in_pouch("firetruck")
k.put_in_pouch("kitten")
k.pouch_content()
# Out:
# ['doll', 'firetruck', 'kitten']

# %%
k.jump(1,0)
k.jump(1,0)
k.jump(1,0)

# %%
print(k)
# Out:
# I am a Kangaroo located at coordinate (3,0)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Write function collatz() that takes a positive integer x as input and prints the Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying this rule to the previous number x in the sequence:
# ####                x = { 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
# ####                        3𝑥+1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
# ### Your function should stop when the sequence gets to number 1. Your

# %%
def collatz(x):
    print(x)
    if x == 1:       
        return
    elif x % 2 == 0:               
        collatz(x // 2)
    else:
        collatz(3 * x + 1)

# %%
collatz(1)
# Out:
# 1

# %%
collatz(10)
# Out:
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Write a recursive method binary() that takes a non-negativeinteger n and prints the binary representation of integer n

# %%
def Binary(n):
    if n < 2:       
        print(n, end='')
    else:
        Binary(n // 2)   
        print(n % 2, end='')

# %%
Binary(0)
# Out:
# 0

# %%
Binary(1)
# Out:
# 1

# %%
Binary(3)
# Out:
# 11

# %%
Binary(9)
# Out:
# 1001

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Implement a class named HeadingParser that can be used to parse an HTML document, and retrieve and print all the headings in the document. You should implement your class as a subclass of HTMLParser, defined in Standard Library module html.parser. When fed a string containing HTML code, your class should print the headings, one per line and in the order in which they appear in the document.Each heading should be indented as follows: an h1 heading should have indentation 0, and h2 heading should have indentation 1, etc. Test your implementation using w3c.html.

# %%
from html.parser import HTMLParser

class HeadingParser(HTMLParser):  #inherits the super class html parser
    def __init__(self):
        super().__init__()
        self.inside_heading = False        #initialize the heading as false
        self.heading_text = ""             #variableto store the text
        self.heading_level = 0             #variable for indentation

    def handle_starttag(self, tag, attrs):
        
        #search for the header tag "h" and also for the digit after h so tag[1:] slicing is used for detecting the digit
        if tag.startswith('h') and tag[1:].isdigit():   
            self.inside_heading = True
            self.heading_level = int(tag[1:])-1  #calculate indentation by using digit of heading tag

    def handle_data(self, data):
        
        if self.inside_heading:
            indentation = "    " * self.heading_level   #spacing for indentation
            self.heading_text = data.strip()    #removes white spaces
            print("{} {}".format(indentation, self.heading_text)) #display the heading content

    def handle_endtag(self, tag):
        if self.inside_heading:

            self.inside_heading = False
            self.heading_text = ""

infile = open("w3c.html")
content = infile.read()
infile.close()

#print headings
hp = HeadingParser()
hp.feed(content)
# Out:
#  W3C Mission
#      Principles

# %% [markdown]
# ## Question 7.

# %%
import requests
import re

def getSites(URL):
    res = requests.get(URL)
    
    sites = re.findall(r'href=["\'](https?://.*?)(?=["\'])', res.text)
    return sites

def webdir(URL, level, indent):
    if level == 0:                       
        return
    
    sites = getSites(URL)
    for site in sites:
        print(' ' * indent + site)
        webdir(site, level - 1, indent + 2)            #recursive call
webdir('https://stackoverflow.com/questions/10732690/offsetting-an-html-anchor-to-adjust-for-fixed-header',2,0)
# Out:
# https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196
# https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a
# https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a
# https://stackoverflow.com/questions/10732690/offsetting-an-html-anchor-to-adjust-for-fixed-header
#   https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196
#   https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a
#   https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a
#   https://stackoverflow.com/questions/10732690/offsetting-an-html-anchor-to-adjust-for-fixed-header
#   https://cdn.sstatic.net/Shared/stacks.css?v=686fb48a484c
#   https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=4c54b08caa7d
#   https://cdn.sstatic.net/Shared/Channels/channels.css?v=bd8fd7ffef3c
#   https://stackoverflow.com
#   https://stackoverflow.co/
# ...

# %% [markdown]
# ## Question 8

# %%
# !pip install ipython-sql
# Out:
# ...
#   Obtaining dependency information for prettytable from https://files.pythonhosted.org/packages/4d/81/316b6a55a0d1f327d04cc7b0ba9d04058cb62de6c3a4d4b0df280cbe3b0b/prettytable-3.9.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for sqlalchemy>=2.0 from https://files.pythonhosted.org/packages/04/88/39f1f5570eb1d28704b4954c97ee91c3b5604f2949ab8ed40b33c90aaad9/SQLAlchemy-2.0.22-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      ---------------------------------------- 41.2/41.2 kB 2.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/2.1 MB 4.8 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 7.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.1 MB 11.8 MB/s eta 0:00:01
# ...

# %%
# %load_ext sql

# %%
# %%sql sqlite:///my_database.db
#
# CREATE TABLE IF NOT EXISTS weather (
#     city TEXT,
#     country TEXT,
#     season TEXT,
#     temperature REAL,
#     rainfall REAL
# );
# Out:
# Done.
# []

# %%
# %%sql sqlite:///my_database.db
#
# INSERT OR REPLACE INTO weather (city, country, season, temperature, rainfall)
# VALUES
#     ('Mumbai', 'India', 'Winter', 24.8, 5.9),
#     ('Mumbai', 'India', 'Spring', 28.4, 16.2),
#     ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
#     ('Mumbai', 'India', 'Fall', 27.6, 346.0),
#     ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
#     ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
#     ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
#     ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
#     ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
#     ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
#     ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
#     ('Cairo', 'Egypt', 'Fall', 22.2, 4.5);
# Out:
# 12 rows affected.
# []

# %%
# %%sql sqlite:///my_database.db
# SELECT * FROM weather
# Out:
# Done.
# [('Mumbai', 'India', 'Winter', 24.8, 5.9),
#  ('Mumbai', 'India', 'Spring', 28.4, 16.2),
#  ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
#  ('Mumbai', 'India', 'Fall', 27.6, 346.0),
#  ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
#  ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
#  ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
#  ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
#  ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
#  ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
#  ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
#  ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)]

# %%
# a)
print("Temperature Data Information")
Temp = %sql SELECT Temperature FROM weather
print(Temp)

# b)
print("Information of All the Cities without repetition")
City = %sql SELECT DISTINCT City FROM weather
print(City) 

# c) 
print("Information of India")
India = %sql SELECT * FROM weather WHERE Country = 'India'
print(India) 

# d)
print("Information of Fall")
Fall_Season = %sql SELECT * FROM weather WHERE Season = 'Fall'
print(Fall_Season)

# e)
print("The city, country, and season for which the average rainfall is between 200 and 400 millimeters")
Avg_RainFall = %sql SELECT City, Country, Season FROM weather GROUP BY City, Country, Season HAVING AVG(Rainfall) BETWEEN 200 AND 400
print(Avg_RainFall) 

# f)
print(" The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order")
Avg_Temprature = %sql SELECT City, Country, Season FROM weather GROUP BY City, Country, Season HAVING AVG(Rainfall) BETWEEN 200 AND 400
print(Avg_Temprature)

# g)
print("The total annual rainfall for Cairo")
Annual_Rainfall = %sql SELECT City, SUM(Rainfall) AS Total_Annual_Rainfall FROM weather WHERE City = 'Cairo' GROUP BY City
print(Annual_Rainfall)

# h)
print("The total rainfall for each season")
Total_Rainfall = %sql SELECT Season, SUM(Rainfall) AS Total_Rainfall FROM weather GROUP BY Season
print(Total_Rainfall)
# Out:
# Temperature Data Information
#  * sqlite:///my_database.db
# Done.
# +-------------+
# | temperature |
# +-------------+
# |     24.8    |
# |     28.4    |
# |     27.9    |
# |     27.6    |
# |     4.2     |
# |     8.3     |
# |     15.7    |
# |     10.4    |
# |     13.6    |
# |     20.7    |
# |     27.7    |
# |     22.2    |
# +-------------+
# Information of All the Cities without repetition
#  * sqlite:///my_database.db
# Done.
# +--------+
# |  city  |
# +--------+
# | Mumbai |
# | London |
# | Cairo  |
# +--------+
# Information of India
#  * sqlite:///my_database.db
# Done.
# +--------+---------+--------+-------------+----------+
# |  city  | country | season | temperature | rainfall |
# +--------+---------+--------+-------------+----------+
# | Mumbai |  India  | Winter |     24.8    |   5.9    |
# | Mumbai |  India  | Spring |     28.4    |   16.2   |
# | Mumbai |  India  | Summer |     27.9    |  1549.4  |
# | Mumbai |  India  |  Fall  |     27.6    |  346.0   |
# ...

# %% [markdown]
# ## Question 9.
# ### Suppose list words is defined as follows:
#
# ### words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over','the', 'lazy', 'dog'] Write list comprehension expressions that use list words and generate the followinglists:

# %% [markdown]
# ### Write list comprehension expressions that use list words and generate the followinglists:
# ### a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE','LAZY', 'DOG']
# ### b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the','lazy', 'dog']
# ### c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in listwords).
# ### d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN','brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5],['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy',4], ['DOG', 'dog', 3]] (the list containing a list for every word of listwords, where each list contains the word in uppercase and lowercase and thelength of the word.)
# ### e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the','lazy', 'dog'] (the list of words in list words containing 4 or more

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over','the', 'lazy', 'dog']
    
upper_case=[word.upper() for word in words]

print(" Result is ", upper_case )
# Out:
#  Result is  ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %%
lower_case=[word.lower() for word in words]
print(" Result is ", lower_case )
# Out:
#  Result is  ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
length_word = [len(word) for word in words]
print(" Result is ", length_word )
# Out:
#  Result is  [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %%
Result_list = [[word.upper(), word.lower(), len(word)] for word in words]
print(" Result is ", Result_list )
# Out:
#  Result is  [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]

# %%
contains_fourChar = [[word] for word in words if len(word) >=4 ]
print(" Result is ", contains_fourChar )
# Out:
#  Result is  [['quick'], ['brown'], ['jumps'], ['over'], ['lazy']]
